# %%
import numpy as np
import pandas as pd
df = pd.read_csv('supermarket_sales - Sheet1.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   float64
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   float64
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df['Branch'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
len(df['Customer type'].unique())
# Out:
# 2

# %%
df['Customer type'].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
df['Payment'].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
# Group the data by Gender and calculate the sum of Total Income
gross_income_by_city = df.groupby('City')['gross income'].sum().reset_index()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(gross_income_by_city['gross income'], labels=gross_income_by_city['City'], autopct='%1.1f%%', colors=['skyblue', 'magenta','coral'])
plt.title('Gross Income Across City')
plt.show()

# %%
# Group the data by Gender and calculate the sum of Total Income
gross_income_by_gender = df.groupby('Gender')['gross income'].sum().reset_index()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(gross_income_by_gender['gross income'], labels=gross_income_by_gender['Gender'], autopct='%1.1f%%', colors=['skyblue', 'coral'])
plt.title('Gross Income Across Gender')
plt.show()

# %%
Total_by_city = df.groupby('City')['Total'].sum().reset_index()# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(Total_by_city['Total'], labels=Total_by_city['City'], autopct='%1.1f%%', colors=['indigo', 'green', 'coral'])
plt.title('Total Across City')
plt.show()

# %%
# Group the data by city and calculate the sum of gross income for each city
city_income = df.groupby('City')['gross income'].sum().reset_index()

# Sort the cities by gross income in descending order
city_income = city_income.sort_values(by='gross income', ascending=False)

# Get the top cities with the highest gross income
top_cities = city_income.head()

# Print the top cities with their gross income
print("Top Cities by Gross Income:")
print(top_cities)
# Out:
# Top Cities by Gross Income:
#         City  gross income
# 1  Naypyitaw     5265.1765
# 2     Yangon     5057.1605
# 0   Mandalay     5057.0320

# %%
# Group the data by City and Branch and calculate the sum of Gross Income
city_branch_income = df.groupby(['City', 'Branch'])['gross income'].sum().reset_index()

# Sort the cities by gross income in descending order
city_branch_income = city_branch_income.sort_values(by='gross income', ascending=False)

# Get the top 5 cities with the highest gross income, considering the branch
top_cities = city_branch_income.head()

# Print the top cities with their gross income and branch
print("Top Cities by Gross Income and Branch:")
print(top_cities)
# Out:
# Top Cities by Gross Income and Branch:
#         City Branch  gross income
# 1  Naypyitaw      C     5265.1765
# 2     Yangon      A     5057.1605
# 0   Mandalay      B     5057.0320

# %%
# Group the data by City and Branch and calculate the sum of Gross Income
city_branch_income = df.groupby(['gross income', 'Branch'])['City'].sum().reset_index()

# Sort the cities by gross income in descending order
city_branch_income = city_branch_income.sort_values(by='gross income', ascending=False)

# Get the top 10 cities with the highest gross income, considering the branch
top_10_cities = city_branch_income.head(10)

# Print the top 10 cities with their gross income and branch
print("Top 10 Cities by Gross Income and Branch:")
print(top_10_cities)
# Out:
# Top 10 Cities by Gross Income and Branch:
#      gross income Branch       City
# 996        49.650      C  Naypyitaw
# 995        49.490      A     Yangon
# 994        49.260      C  Naypyitaw
# 993        48.750      C  Naypyitaw
# 992        48.690      B   Mandalay
# 991        48.685      B   Mandalay
# 990        48.605      C  Naypyitaw
# 989        47.790      C  Naypyitaw
# 988        47.720      C  Naypyitaw
# 987        45.325      A     Yangon

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
sns.boxplot(x='Branch', y='Unit price', data= df, palette='rainbow')
# Out:
# <Axes: xlabel='Branch', ylabel='Unit price'>

# %%
# Example: Bar chart to show average gross income by product line for each gender
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

sns.barplot(x="Product line", y="gross income", hue="Gender", data=df)

plt.title("Average Gross Income by Product Line and Gender")
plt.xlabel("Product Line")
plt.ylabel("Average Gross Income")
plt.xticks(rotation=45)

plt.show()

# %%
# Perform a two-way ANOVA
result = stats.f_oneway(*[df[df['City'] == city]['Tax 5%'] for city in df['City'].unique()],
                       *[df[df['Branch'] == branch]['Tax 5%'] for branch in df['Branch'].unique()])

# Set the significance level (alpha)
alpha = 0.05

# Print the results
print("F-statistic:", result.statistic)
print("P-value:", result.pvalue)

if result.pvalue < alpha:
    print("There is a significant relationship between City, Branch, and Taxes Paid.")
else:
    print("There is no significant relationship between City, Branch, and Taxes Paid.")
# Out:
# F-statistic: 0.5884517218397469
# P-value: 0.7090289831549574
# There is no significant relationship between City, Branch, and Taxes Paid.

# %%
# Set the significance level (alpha)
alpha = 0.05

# Print the results
print("F-statistic:", result.statistic)
print("P-value:", result.pvalue)

if result.pvalue < alpha:
    print("There is a significant relationship between City, Branch, and Gross Income.")
else:
    print("There is no significant relationship between City, Branch, and Gross Income.")
# Out:
# F-statistic: 0.5884517218397469
# P-value: 0.7090289831549574
# There is no significant relationship between City, Branch, and Gross Income.

# %%
# Group the data by City, Branch, and Customer Type, and count the number of occurrences
customer_types_count = df.groupby(['City', 'Branch', 'Customer type']).size().reset_index(name='Count')

# Print the result
print("Number of Customer Types per City and Branch:")
print(customer_types_count)
# Out:
# Number of Customer Types per City and Branch:
#         City Branch Customer type  Count
# 0   Mandalay      B        Normal      2
# 1  Naypyitaw      C        Member      3
# 2  Naypyitaw      C        Normal      3
# 3     Yangon      A        Member      1
# 4     Yangon      A        Normal      1

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['cogs'], df['gross income'], alpha=0.5)
plt.title("Relationship between Cost of Goods Sold and Gross Income")
plt.xlabel("Cost of Goods Sold")
plt.ylabel("Gross Income")
plt.grid(True)

plt.show()

# %%
# Example: Bar chart to show average gross income by product line for each gender
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

sns.barplot(x="Product line", y="gross income", hue="Gender", data=df)

plt.title("Average Gross Income by Product Line and Gender")
plt.xlabel("Product Line")
plt.ylabel("Average Gross Income")
plt.xticks(rotation=45)

plt.show()

# %%
# Create a bar plot using seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x='Payment', y='Total', hue='Gender', data=df)
plt.title('Total Income Across Payment Types and Gender')
plt.xlabel('Payment Type')
plt.ylabel('Total Income')
plt.show()

# %%
sns.distplot(df['Total'],kde=False,bins=30)
# Out:
# C:\Users\somoy\AppData\Local\Temp\ipykernel_13380\170169680.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total'],kde=False,bins=30)
# <Axes: xlabel='Total'>

# %%
sns.jointplot(x='Total', y='Rating', data=df,kind='scatter')

# %%
# Create a count plot using seaborn
plt.figure(figsize=(10, 6))
sns.countplot(x='Payment', hue='Gender', data=df)
plt.title('Payment Types Used Across Genders')
plt.xlabel('Payment Type')
plt.ylabel('Count')
plt.show()

# %%
# Group the data by Gender and Payment, and count the occurrences
payment_by_gender = df.groupby(['Gender', 'Payment']).size().reset_index(name='Count')

# Print the result
print("Payment Types Used Across Different Genders:")
print(payment_by_gender)
# Out:
# Payment Types Used Across Different Genders:
#    Gender      Payment  Count
# 0  Female         Cash    178
# 1  Female  Credit card    163
# 2  Female      Ewallet    160
# 3    Male         Cash    166
# 4    Male  Credit card    148
# 5    Male      Ewallet    185

# %%
sns.distplot(df['Total'],kde=False,bins=30)
# Out:
# C:\Users\somoy\AppData\Local\Temp\ipykernel_13380\170169680.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total'],kde=False,bins=30)
# <Axes: xlabel='Total'>

# %%
# Create a bar plot using seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x='Payment', y='Total', hue='Gender', data=df)
plt.title('Total Income Across Payment Types and Gender')
plt.xlabel('Payment Type')
plt.ylabel('Total income')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Select the relevant columns
selected_columns = ["Total", "Quantity", "Tax 5%", "cogs", "gross income", "Rating"]

# Create a subset of the data with the selected columns
subset_data = df[selected_columns]

# Calculate the correlation matrix
correlation_matrix = subset_data.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Plot")
plt.show()

# %%
# Group the data by Product Line and calculate the sum of Total Income
total_income_by_product_line = df.groupby('Product line')['Total'].sum().reset_index()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(total_income_by_product_line['Total'], labels=total_income_by_product_line['Product line'], autopct='%1.1f%%', startangle=140, colors=['lightgreen', 'blue', 'red', 'yellow', 'magenta','orange'])
plt.title('Total Income Across Product Lines')
plt.show()

# %%
# Group the data by Product Line and City, and calculate the sum of Gross Income
product_city_income = df.groupby(['Product line', 'City'])['gross income'].sum().reset_index()

# Print the gross income generated per product line across the cities
print("Gross Income per Product Line Across Cities:")
print(product_city_income)
# Out:
# Gross Income per Product Line Across Cities:
#               Product line       City  gross income
# 0   Electronic accessories   Mandalay      811.9735
# 1   Electronic accessories  Naypyitaw      903.2845
# 2   Electronic accessories     Yangon      872.2435
# 3      Fashion accessories   Mandalay      781.5865
# 4      Fashion accessories  Naypyitaw     1026.6700
# 5      Fashion accessories     Yangon      777.7385
# 6       Food and beverages   Mandalay      724.5185
# 7       Food and beverages  Naypyitaw     1131.7550
# 8       Food and beverages     Yangon      817.2905
# 9        Health and beauty   Mandalay      951.4600
# 10       Health and beauty  Naypyitaw      791.2060
# 11       Health and beauty     Yangon      599.8930
# 12      Home and lifestyle   Mandalay      835.6745
# 13      Home and lifestyle  Naypyitaw      661.6930
# 14      Home and lifestyle     Yangon     1067.4855
# 15       Sports and travel   Mandalay      951.8190
# ...
